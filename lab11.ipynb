# %%
import requests
from bs4 import BeautifulSoup
import csv

def fetch_bbc_news():
    url = 'https://marathi.abplive.com/'
    response = requests.get(url)

    # Перевірте статус відповіді; 200 означає, що все гаразд
    if response.status_code != 200:
        print(f'Failed to retrieve the page with status code: {response.status_code}')
        return None

    soup = BeautifulSoup(response.content, 'html.parser')

    # Збір заголовків новин
    headlines = []
    for article in soup.find_all('p'):
        headline_text = article.text.strip()
        if headline_text:  # Перевірка на наявність тексту
            headlines.append(headline_text)

    # Збереження заголовків новин у файл CSV
    with open('marathi_headlines.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Headline'])  # Заголовок стовпця
        for headline in headlines:
            writer.writerow([headline])

# Виклик функції
fetch_bbc_news()

# %%
import csv

# Ім'я CSV-файлу
csv_filename = 'marathi_headlines.csv'

# Змінна для збереження вмісту файлу
marathi_text = ''

# Відкриваємо CSV-файл для читання
with open(csv_filename, mode='r', encoding='utf-8') as file:
    reader = csv.reader(file)

    # Ітеруємося через рядки CSV-файлу та додаємо їх до змінної text
    for row in reader:
        marathi_text += ', '.join(row) + '\n'

# Виводимо вміст
print(marathi_text)
# Out:
# Headline
# Jyotiraditya Shinde Exclusive : मी त्यांना नतमस्तक, ज्योतिरादित्य शिंदेंची मराठीत पहिली प्रतिक्रिया, मुख्यमंत्रीपदावर म्हणाले,
# थेट सीएम केसीआरना घेरुन शड्डू ठोकला अन् सत्ताही खेचली; रेवंत रेड्डी तेलंगणामध्ये काँग्रेससाठी गेमचेंजर कसे ठरले?
# ना भाजप, ना काँग्रेस, या पक्षाला विधानसभा निवडणुकीत मिळाला पहिला विजय
# तीन राज्यात भाजप जिंकले तरी 2024 मध्ये महाराष्ट्रात भाजपचा पराभव निश्चित : शरद पवार
# Rajasthan Election Result Live : राजस्थानात वसुंधरा राजे नव्हे तर बालकनाथ की आणखी कोणी? भाजपची सत्ता आल्यास मुख्यमंत्री कोण होणार?
# आमचा निर्णय काहींना आवडला नाही, पण देशाला मोदींशिवाय पर्याय नाही : अजित पवार
# Election Result 2023: 2024 मध्ये इंडिया आघाडीचं पानिपत होईल,भाजपच्या विजयानंतर शिंदेंची प्रतिक्रिया
# Jyotiraditya Shinde Exclusive : मी त्यांना नतमस्तक, ज्योतिरादित्य शिंदेंची मराठीत पहिली प्रतिक्रिया, मुख्यमंत्रीपदावर म्हणाले,
# ना भाजप, ना काँग्रेस, या पक्षाला विधानसभा निवडणुकीत मिळाला पहिला विजय
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.8 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=f202e401bdc40090c59a66187d62d113f48b8499699f757b449840700f854c88
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator

def translate_to_english(marath_text):
    translator = Translator()
    translated_text_english = translator.translate(marathi_text, src='mr', dest='uk')
    return translated_text_english.text



# Переклад тексту на українську
text = translate_to_english(marathi_text)
text2 = translate_to_english(marathi_text)

print("Маратхі текст:", marathi_text)
print("Переклад на англійську:", text)
# Видаляємо слово "заголовки" з тексту
text = text.replace("заголовки", "")
# Out:
# Маратхі текст: Headline
# Jyotiraditya Shinde Exclusive : मी त्यांना नतमस्तक, ज्योतिरादित्य शिंदेंची मराठीत पहिली प्रतिक्रिया, मुख्यमंत्रीपदावर म्हणाले,
# थेट सीएम केसीआरना घेरुन शड्डू ठोकला अन् सत्ताही खेचली; रेवंत रेड्डी तेलंगणामध्ये काँग्रेससाठी गेमचेंजर कसे ठरले?
# ना भाजप, ना काँग्रेस, या पक्षाला विधानसभा निवडणुकीत मिळाला पहिला विजय
# तीन राज्यात भाजप जिंकले तरी 2024 मध्ये महाराष्ट्रात भाजपचा पराभव निश्चित : शरद पवार
# Rajasthan Election Result Live : राजस्थानात वसुंधरा राजे नव्हे तर बालकनाथ की आणखी कोणी? भाजपची सत्ता आल्यास मुख्यमंत्री कोण होणार?
# आमचा निर्णय काहींना आवडला नाही, पण देशाला मोदींशिवाय पर्याय नाही : अजित पवार
# Election Result 2023: 2024 मध्ये इंडिया आघाडीचं पानिपत होईल,भाजपच्या विजयानंतर शिंदेंची प्रतिक्रिया
# Jyotiraditya Shinde Exclusive : मी त्यांना नतमस्तक, ज्योतिरादित्य शिंदेंची मराठीत पहिली प्रतिक्रिया, मुख्यमंत्रीपदावर म्हणाले,
# ना भाजप, ना काँग्रेस, या पक्षाला विधानसभा निवडणुकीत मिळाला पहिला विजय
# ...

# %%
# !pip install spacy
# !python -m spacy download uk_core_news_sm
# Out:
# ...
# 2023-12-03 09:22:13.391280: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 09:22:13.391353: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 09:22:13.391401: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 09:22:13.404001: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import spacy

# Завантаження моделі для української мови
nlp = spacy.load("uk_core_news_sm")

# %%
import re

def preprocess_text(text):
    # Видаляємо літери, які не є кирилицею
    text = re.sub(r'[^а-яА-ЯіІїЇєЄёЁa-zA-Z ]', '', text)

    return text

# %%
def preprocess_text(text):
    # Видаляємо числа
    text = re.sub(r'\d+', '', text)

    return text

# %%
def preprocess_text(text):
    # Видаляємо подвійні пробіли та нормалізуємо інші пробіли
    text = ' '.join(text.split())

    return text

# %%
import string

def preprocess_text(text):
    # Видаляємо всі символи пунктуації
    text = text.translate(str.maketrans('', '', string.punctuation))

    return text

# %%
def preprocess_text(text):
    # Обробка тексту за допомогою spaCy
    doc = nlp(text)

    # Токенізація тексту і видалення стоп-слів
    filtered_tokens = [token.text for token in doc if not token.is_stop]

    return filtered_tokens

text = text.replace('\n', ' ')
text = text.replace('Заголовок', '')

# %%
def flatten_list(lst):
    for item in lst:
        if isinstance(item, list):
            yield from flatten_list(item)
        else:
            yield str(item)

preprocessed_text = preprocess_text(text)
flattened_text = list(flatten_list(preprocessed_text))
formatted_text = split_text(' '.join(flattened_text), 100)
print(formatted_text)
# Out:
#   Jyotiraditya Shinde Ексклюзивний : поклонився , першою реакцією Джотірадитії Шінде Маратхі , - зая
# вив головному міністру , Live CM Kcra постукав тіні витягнув силу;Як Revant Reddy грою Чергнер Конгр
# есу Телангані ? BJP , Конгресу , партія отримала першу перемогу виборах Асамблеї BJP виграє штати ,
# поразка BJP Махараштрі 2024 : Шарад Павар Результат виборів Раджастана прямому ефірі : вазундхара ко
# ролі Раджастані , Баланат хтось інший?Хто головним міністром , БДП прийде влади ? сподобалось рішенн
# я , країні іншого вибору , Моді : Аджіт Павар Індія лідирує лідерство 2023 : 2024 , реакція Шінде пе
# ремоги BJP Jyotiraditya Shinde Ексклюзивний : поклонився , першою реакцією Джотірадитії Шінде Маратх
# і , - заявив головному міністру , BJP , Конгресу , партія отримала першу перемогу виборах Асамблеї M
# anikrao Thaare Telangana Результати 2023 : Маратхі обличчя перемоги Конгресі Телангані ексклюзив Ест
# ...

# %%
# Використовуємо множину для видалення дублікатів
unique_words = list(set(preprocessed_text))

# Виводимо унікальні слова у вигляді списку
print(unique_words)
# Out:
# ['питання', 'злочин', 'Lives', 'виступили', 'JA', 'повинні', 'ABP', 'Vs', 'Хворий', 'дорівнює', 'Шарма', 'катта', '-стоп', 'vs', 'Каші', 'Будинок', 'Вивільняють', 'Хел', 'Dhamal', 'красуня', 'брата', 'Лаліт', 'готівкою', 'стійкого', 'Janhvi', 'повинен', 'отримає', 'будівництво', 'уряду', 'футболу', 'проса', 'відзначається', 'чашка23', 'частини', 'кокосовий', 'відбувається', 'гороскопів', 'просочилися', 'Яубай', 'команда', 'нова', 'Максимум', 'соромно', 'Індія!Вирішальний', 'Алія', 'Кубка', 'Режисер', 'Кокос', 'мережах', 'Шелар', 'Шубмана', 'Бхатт', 'Санголі', 'Профіль', 'Поради', 'Ахмедабад', 'Гілл', 'планет', 'штампували', 'Kangaroo', 'країни', ':', 'вірус', 'India', 'відповідати', 'Чак', 'Бхуджбал', 'табличок', 'Марафи', 'отримав', 'договору', 'Mandir', 'продає', 'горіх', 'Вішваната', 'повернув', 'Pujan', 'Талука', 'куточках', '...', 'заворушеннями', 'шкідливі', 'Pranaprastha', 'Lightboard', 'Девендра', 'Ayodhya', 'Астрологія', 'ентузіазмом', 'просоної', 'грають', 'Панді;Мумбаї', '
# ...

# %%
import pandas as pd

# Список слів і їх оцінок настрою
word_sentiments = {
    'питання': 1,
    'злочин': -3,
    'Lives': 2,
    'виступили': 1,
    'JA': 0,
    'повинні': 0,
    'ABP': 0,
    'Vs': 0,
    'Хворий': -2,
    'дорівнює': 0,
    'Шарма': 0,
    'катта': 0,
    '-стоп': -1,
    'vs': 0,
    'Каші': 0,
    'Будинок': 0,
    'Вивільняють': 2,
    'Хел': 0,
    'Dhamal': 0,
    'красуня': 3,
    'брата': 0,
    'Лаліт': 0,
    'готівкою': 0,
    'стійкого': 1,
    'Janhvi': 0,
    'повинен': -1,
    'отримає': 2,
    'будівництво': 3,
    'уряду': 2,
    'футболу': 3,
    'проса': 0,
    'відзначається': 0,
    'чашка23': 0,
    'частини': 0,
    'кокосовий': 0,
    'відбувається': 0,
    'гороскопів': 0,
    'просочилися': -1,
    'Яубай': 0,
    'команда': 0,
    'нова': 2,
    'Максимум': 2,
    'соромно': -2,
    'Індія!Вирішальний': 1,
    'Алія': 0,
    'Кубка': 0,
    'Режисер': 0,
    'Кокос': 0,
    'мережах': 0,
    'Шелар': 0,
    'Шубмана': 0,
    'Бхатт': 0,
    'Санголі': 0,
    'Профіль': 0,
    'Поради': 0,
    'Ахмедабад': 0,
    'Гілл': 0,
    'планет': 0,
    ':': 0,
    'вірус': -5,
    'India': 0,
    'відповідати': 0,
    'Чак': 0,
    'Бхуджбал': 0,
    'табличок': 0,
    'Марафи': 0,
    'отримав': 0,
    'договору': 0,
    'Mandir': 0,
    'продає': 0,
    'горіх': 0,
    'Вішваната': 0,
    'повернув': 0,
    'Pujan': 0,
    'Талука': 0,
    'куточках': 0,
    '...': 0,
    'заворушеннями': -2,
    'шкідливі': -4,
    'Pranaprastha': 0,
    'Lightboard': 0,
    'Девендра': 0,
    'Ayodhya': 0,
    'Астрологія': 0,
    'ентузіазмом': 0,
    'просоної': 0,
    'грають': 0,
    'Панді;Мумбаї': 0,
    'Наві': 0,
    'Політика': 3,
    'оновлення': 0,
    'Сараті': 0,
    'Візьміть': 0,
    'бурхливими': -2,
    'фільму': 0,
    'Group!Дивізіональні': 0,
    'подорож': 0,
    'країн': 0,
    'віднесли': 0,
    'Декор': 0,
    'мільйонів': 0,
    'головної': 0,
    'поверхневій': 0,
    'планети': 0,
    'Природознавство': 0,
    'сроки': 0,
    'Масові': 0,
    'Ут': 0,
    'суперкарами': 0,
    'завершився': 0,
    'Залізнодорожній': 0,
    'звірят': 0,
    'Велі': 0,
    'затягнувся': 0,
    'слів': 0,
    'прийшов': 0,
    'розповів': 0,
    'Про': 0,
    'театр': 0,
    'роблять': 0,
    'бордюри': 0,
    'різноманітних': 0,
    'змін': 0,
    'кінофестивалю': 0,
    'постачання': 0,
    'району': 0,
    'шоу': 0,
    'Vichar': 0,
    'вибачився': -2,
    'респіратори': -5,
    'Імперії': -5,
    'Земля': 5,
    'Завантажуємо': 0,
    '2023': 0,
    'висловлювання': 0,
    'Умань': 0,
    'політики': 5,
    'Промені': 0,
    'професора': 2,
    'голову': 0,
    'вірусу': -5,
    'Aap': 0,
    'інфраструктура': 5,
    'горизонту': 3,
    'розпросторовують': 5,
    'Талав': 0,
    'сонця': 5,
    'Гоа': 0,
    'Durgotsav': 0,
    'здолали': 3,
    'запуску': 1,
    'Фотогалерея': 2,
    'понад': 0,
    'панели': 0,
    'Фортеця': 0  # Виправлено помилку - додано оцінку настрою для слова "Фортеця"
      }
word_sentiments_list = []

# Оцінки настрою для кожного слова в текстах
for text in preprocessed_text:
    words = text.split()  # Розділити текст на окремі слова
    sentiment_scores = [word_sentiments.get(word, 0) for word in words]  # Отримати оцінку для кожного слова, за замовчуванням 0, якщо слово не знайдено
    word_sentiments_list.append(sentiment_scores)

# Створюємо DataFrame для збереження оцінок настрою для кожного слова
data = pd.DataFrame({"Text": preprocessed_text, "Word Sentiments": word_sentiments_list})

# Виводимо таблицю
print(data)
# Out:
#           Text Word Sentiments
# 0                           []
# 1        Живий             [0]
# 2    телевізор             [0]
# 3       Новини             [0]
# 4          Хел             [0]
# ..         ...             ...
# 699      драма             [0]
# 700    Режисер             [0]
# 701          :             [0]
# 702      Маніш             [0]
# 703      Шарма             [0]
#
# [704 rows x 2 columns]

# %%
# Розділімо текст на речення за допомогою роздільника "."
sentences = text2.split(".")

# Ініціалізуємо список для збереження настрою кожного речення
sentence_sentiments = []

# Обходимо кожне речення і обчислюємо суму оцінок слів
for sentence in sentences:
    # Розділімо речення на окремі слова
    words = sentence.split()

    # Знайдемо оцінки для кожного слова та обчислимо суму
    sentiment_scores = [word_sentiments.get(word, 0) for word in words]
    sentence_sentiment = sum(sentiment_scores)

    # Виводимо результати для кожного речення
    print(f"Речення:")
    print(f"Текст: {sentence.strip()}")
    print(f"Настрій: {sentence_sentiment}\n")
# Out:
# Речення:
# Текст: Заголовок
# Живий телевізор
# Новини
# Хел Маджа
# Політика Махараштри
# Верхні заголовки
# Моя катта
# Ніколи раніше Team India дорівнює Пакистану!Що відбувається після перемоги Австралії?
# Організаційне будівництво від Shiv Sena Thackeray Group!Дивізіональні лідери Thackeray Group заявляють: "Ці" ці "лідери віднесли велику відповідальність
# Прем'єр -міністр Тірупаті Баладжі Сакад!Моді по стопах лорда Венкатешвара
# Жовті сповіщення перед передмістям, Тане та Пальгар з Мумбаї, можливість дощів з бурхливими вітрами протягом наступних 48 годин
# Настрій: 4
#
# Речення:
# Текст: Аджіт Дада отримав бунгало в Балекилі Девендра Фаднавіс;Буде нова адреса
# Настрій: 2
#
# Речення:
# Текст:
# Настрій: 0
#
# Речення:
# Текст: Аджіт Павар Група обвинувачених в Антарвалі Сараті Стоун Президент Талука, стверджує помилковий злочин, Віджай Сінгх Пандіт Март
# Настрій: 0
#
# Речення:
# Текст: Якщо уряд хоче впасти
# Настрій: 0
#
# Речення:
# Текст:
# Настрій: 0
#
# Речення:
# ...

# %%
# Розділімо текст на речення за допомогою роздільника "."
sentences = text2.split(".")

# Ініціалізуємо список для збереження настрою кожного речення
sentence_sentiments = []

# Обходимо кожне речення і обчислюємо суму оцінок слів
for sentence in sentences:
    # Розділімо речення на окремі слова
    words = sentence.split()

    # Знайдемо оцінки для кожного слова та обчислимо суму
    sentiment_scores = [word_sentiments.get(word, 0) for word in words]
    sentence_sentiment = sum(sentiment_scores)

    # Перевіримо, чи не дорівнює sentence_sentiment 0, і виведемо результати тільки у цьому випадку
    if sentence_sentiment != 0:
        print(f"Речення:")
        print(f"Текст: {sentence.strip()}")
        print(f"Настрій: {sentence_sentiment}\n")
# Out:
# Речення:
# Текст: Заголовок
# Живий телевізор
# Новини
# Хел Маджа
# Політика Махараштри
# Верхні заголовки
# Моя катта
# Ніколи раніше Team India дорівнює Пакистану!Що відбувається після перемоги Австралії?
# Організаційне будівництво від Shiv Sena Thackeray Group!Дивізіональні лідери Thackeray Group заявляють: "Ці" ці "лідери віднесли велику відповідальність
# Прем'єр -міністр Тірупаті Баладжі Сакад!Моді по стопах лорда Венкатешвара
# Жовті сповіщення перед передмістям, Тане та Пальгар з Мумбаї, можливість дощів з бурхливими вітрами протягом наступних 48 годин
# Настрій: 4
#
# Речення:
# Текст: Аджіт Дада отримав бунгало в Балекилі Девендра Фаднавіс;Буде нова адреса
# Настрій: 2
#
# Речення:
# Текст: Велика заява спікера Асамблеї
# Візьміть Комітет Шінде, Верховний Суд каже, що суспільство Маратха не сидить у ОБК;Попит на Чхаган Бхудбал
# Нарешті штампували в будинку Панді;Мумбаї повернув пакет готівкою в будинку крор
# ...
