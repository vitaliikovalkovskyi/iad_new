# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import scipy.stats as stats
import re
# !pip install hvplot

import hvplot.pandas
import statsmodels.api as sm
import holoviews as hv
hv.extension('bokeh')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 18.4 MB/s eta 0:00:00
# ...
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
sns.set(style="darkgrid")
df = pd.read_excel('/content/drive/MyDrive/vnz2019.xlsx')
df = df.drop(0, axis=0)

# Якщо ви хочете оновити індекси після видалення рядка, використовуйте reset_index:
df = df.reset_index(drop=True)
df = df.iloc[:, 1:]
df = df.dropna()
display(df)
# Out:
#      Номер ЄДЕБО                         Назва закладу вищої освіти  \
# 0             41  Київський національний університет ім. Тараса ...
# 1              2  Донбаська національна академія будівництва і а...
# 2              3  Полтавський національний педагогічний універси...
# 3              7  Національний університет біоресурсів і природо...
# 4              9  Національний університет водного господарства ...
# ..           ...                                                ...
# 143         3781  ДВНЗ "Криворізький державний педагогічний унів...
# 144         3969  Державний університет інфраструктури та технол...
# 156          201            Національний фармацевтичний університет
# 164          118  Одеська національна музична Академія ім. А.В.Н...
# 167          357  Національна музична академія України ім. П.І.Ч...
#
#                       Область  \
# 0                      м.Київ
# 1            Донецька область
# 2          Полтавська область
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 0 to 167
# Data columns (total 25 columns):
#  #   Column                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                      --------------  -----
#  0   Номер ЄДЕБО                                                                                                                                 142 non-null    int64
#  1   Назва закладу вищої освіти                                                                                                                  142 non-null    object
#  2   Область                                                                                                                                     142 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Номер ЄДЕБО', 'Назва закладу вищої освіти', 'Область',
#        'Середній конкурсний бал зарахованих абітурієнтів',
#        'Середній конкурсний бал зарахованих \nабітурієнтів на навчання за державним замовленням',
#        'Середній конкурсний бал зарахованих \nабітурієнтів на навчання за контрактом',
#        'Середній бал ЄВІ з іноземної мови випускників закладу, які були зараховані до іншого або цього закладу',
#        'Студенти, які навчаються за денною формою навчання за державним замовленням',
#        'Студенти, які навчаються за заочною формою навчання за державним замовленням',
#        'Всього студентів, які навчаються за державним замовленням\n(приведений континент)',
#        'Всього студентів, які навчаються за контрактом\n(приведений континент)',
#        'Частка студентів, які навчаються за державним замовленням у загальній кількості (приведений контингент)',
#        'Педагогічний персонал', 'Науково-педагогічний персонал',
# ...

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import holoviews as hv
hv.extension('bokeh')
df.hvplot.hist(by='Середній конкурсний бал зарахованих абітурієнтів', subplots=False, width=1000)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ...

# %%
import holoviews as hv
hv.extension('bokeh')
df.hvplot.hist("Середній конкурсний бал зарахованих абітурієнтів")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ...

# %%
import holoviews as hv
hv.extension('bokeh')
df.hvplot.scatter(x='Середній конкурсний бал зарахованих \nабітурієнтів на навчання за державним замовленням', y='Середній конкурсний бал зарахованих абітурієнтів')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Scatter   [Середній конкурсний бал зарахованих
# ...

# %%
df.columns
# Out:
# Index(['Номер ЄДЕБО', 'Назва закладу вищої освіти', 'Область',
#        'Середній конкурсний бал зарахованих абітурієнтів',
#        'Середній конкурсний бал зарахованих \nабітурієнтів на навчання за державним замовленням',
#        'Середній конкурсний бал зарахованих \nабітурієнтів на навчання за контрактом',
#        'Середній бал ЄВІ з іноземної мови випускників закладу, які були зараховані до іншого або цього закладу',
#        'Студенти, які навчаються за денною формою навчання за державним замовленням',
#        'Студенти, які навчаються за заочною формою навчання за державним замовленням',
#        'Всього студентів, які навчаються за державним замовленням\n(приведений континент)',
#        'Всього студентів, які навчаються за контрактом\n(приведений континент)',
#        'Частка студентів, які навчаються за державним замовленням у загальній кількості (приведений контингент)',
#        'Педагогічний персонал', 'Науково-педагогічний персонал',
# ...

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True,  linewidths = 0.8)
#plt.title('Теплокарта кореляції')
plt.show()
# Out:
# <ipython-input-7-f2629f302c13>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
X = df[['Середній конкурсний бал зарахованих \nабітурієнтів на навчання за державним замовленням', 'Середній конкурсний бал зарахованих \nабітурієнтів на навчання за контрактом',
               'Середній бал ЄВІ з іноземної мови випускників закладу, які були зараховані до іншого або цього закладу', 'Студенти, які навчаються за денною формою навчання за державним замовленням']]
y = df['Середній конкурсний бал зарахованих абітурієнтів']

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')

def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lin_reg.intercept_)
# Out:
# 10.40203860501876

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                                                     Coefficient
# Середній конкурсний бал зарахованих \nабітурієн...     0.415028
# Середній конкурсний бал зарахованих \nабітурієн...     0.494263
# Середній бал ЄВІ з іноземної мови випускників з...     0.020949
# Студенти, які навчаються за денною формою навча...     0.000242

# %%
pred = lin_reg.predict(X)

# %%
import holoviews as hv
hv.extension('bokeh')
pd.DataFrame({'True Values': y, 'Predicted Values': pred}).hvplot.scatter(x='True Values', y='Predicted Values')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Scatter   [True Values]   (Predicted Values)

# %%
import holoviews as hv
hv.extension('bokeh')
pd.DataFrame({'Error Values': (y - pred)}).hvplot.kde()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ...

# %%
results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y, pred) , cross_val(LinearRegression())]],
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])

# %%
from sklearn.linear_model import RANSACRegressor

model = RANSACRegressor(base_estimator=LinearRegression(), max_trials=100)
model.fit(X, y)


results_df_2 = pd.DataFrame(data=[["Robust Regression", *evaluate(y, pred) , cross_val(RANSACRegressor())]],
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ransac.py:343: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.1 and will be removed in 1.3.
#   warnings.warn(
# <ipython-input-23-df3cb7b07922>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results_df_2, ignore_index=True)

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=100, solver='cholesky', tol=0.0001, random_state=42)
model.fit(X, y)
pred = model.predict(X)


results_df_2 = pd.DataFrame(data=[["Ridge Regression", *evaluate(y, pred) , cross_val(Ridge())]],
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
# Out:
# <ipython-input-24-7dc84042a0c9>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results_df_2, ignore_index=True)

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha=0.1,
              precompute=True,
#               warm_start=True,
              positive=True,
              selection='random',
              random_state=42)


results_df_2 = pd.DataFrame(data=[["Lasso Regression", *evaluate(y, pred) , cross_val(Lasso())]],
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
# Out:
# <ipython-input-25-fae0344dfc25>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results_df_2, ignore_index=True)

# %%
from sklearn.linear_model import ElasticNet

model = ElasticNet(alpha=0.1, l1_ratio=0.9, selection='random', random_state=42)


results_df_2 = pd.DataFrame(data=[["Elastic Net Regression", *evaluate(y, pred) , cross_val(ElasticNet())]],
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
# Out:
# <ipython-input-26-6e37b95eb7ad>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results_df_2, ignore_index=True)

# %%
import holoviews as hv
hv.extension('bokeh')
pd.DataFrame({'True Values': y, 'Predicted Values': pred}).hvplot.scatter(x='True Values', y='Predicted Values')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Scatter   [True Values]   (Predicted Values)

# %%
results_df
# Out:
#                     Model       MAE       MSE      RMSE  R2 Square  \
# 0       Linear Regression  2.100581  9.371497  3.061290   0.899454
# 1       Robust Regression  2.100581  9.371497  3.061290   0.899454
# 2        Ridge Regression  2.103048  9.373069  3.061547   0.899437
# 3        Lasso Regression  2.103048  9.373069  3.061547   0.899437
# 4  Elastic Net Regression  2.103048  9.373069  3.061547   0.899437
#
#    Cross Validation
# 0          0.894057
# 1          0.883574
# 2          0.894058
# 3          0.894059
# 4          0.894108

# %%
import matplotlib.pyplot as plt

# Встановіть межі шкали
plt.xlim(0.89, 0.91)

# Створіть графік
results_df['R2 Square'].plot(kind='barh', figsize=(12, 8))

# Додайте підписи значень
for i, v in enumerate(results_df['R2 Square']):
    plt.text(v, i, f'{v:.5f}', va='center', color='black', fontweight='bold')

# Додайте назву графіку та підписи вісей
plt.title('R2 Square для різних моделей')
plt.xlabel('R2 Square')
plt.ylabel('Model')

# Відобразіть графік
plt.show()
